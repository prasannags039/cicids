# %%
import pandas as pd

# %%
from google.colab import files

# %%
fe=files.upload()
# Out:
#      <input type="file" id="files-d4519bf8-97bf-4248-a7e0-b193390a874c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4519bf8-97bf-4248-a7e0-b193390a874c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_excel(r"newdatasetcici.xlsx")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Flow ID            5 non-null      object
#  1   Source IP          5 non-null      object
#  2   Destination IP     5 non-null      object
#  3   Source Port        5 non-null      int64
#  4   Destination Port   5 non-null      int64
#  5   Protocol           5 non-null      object
#  6   Flow Duration      5 non-null      int64
#  7   Total Fwd Packets  5 non-null      int64
#  8   Total Bwd Packets  5 non-null      int64
#  9   Fwd Packet Length  5 non-null      int64
#  10  Bwd Packet Length  5 non-null      int64
#  11  Label              5 non-null      object
# dtypes: int64(7), object(5)
# memory usage: 612.0+ bytes

# %%
df=pd.DataFrame(data)

# %%
df.isnull()
# Out:
#    Flow ID  Source IP  Destination IP  Source Port  Destination Port  \
# 0    False      False           False        False             False
# 1    False      False           False        False             False
# 2    False      False           False        False             False
# 3    False      False           False        False             False
# 4    False      False           False        False             False
#
#    Protocol  Flow Duration   Total Fwd Packets  Total Bwd Packets  \
# 0     False           False              False              False
# 1     False           False              False              False
# 2     False           False              False              False
# 3     False           False              False              False
# 4     False           False              False              False
#
#    Fwd Packet Length  Bwd Packet Length  Label
# 0              False              False  False
# 1              False              False  False
# ...

# %%
df.describe()
# Out:
#        Source Port  Destination Port  Flow Duration   Total Fwd Packets  \
# count      5.00000          5.000000        5.000000           5.000000
# mean     208.00000      10422.600000    72000.000000           7.800000
# std      215.53886      22971.984096    37013.511047           2.863564
# min       21.00000         22.000000    30000.000000           4.000000
# 25%       53.00000         53.000000    40000.000000           6.000000
# 50%       80.00000         80.000000    80000.000000           8.000000
# 75%      443.00000        443.000000    90000.000000          10.000000
# max      443.00000      51515.000000   120000.000000          11.000000
#
#        Total Bwd Packets  Fwd Packet Length  Bwd Packet Length
# count           5.000000           5.000000           5.000000
# mean            5.800000         880.000000         570.000000
# std             3.114482         286.356421         299.165506
# min             2.000000         500.000000         200.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates()
# Out:
#   Flow ID     Source IP Destination IP  Source Port  Destination Port  \
# 0      F1   192.168.0.2     172.16.0.3          443             51515
# 1      F2   192.168.0.5     172.16.0.3           80                80
# 2      F3   192.168.0.2    172.16.0.10          443               443
# 3      F4  192.168.0.10    172.16.0.11           21                22
# 4      F5   192.168.0.7     172.16.0.3           53                53
#
#    Protocol  Flow Duration   Total Fwd Packets  Total Bwd Packets  \
# 0   TCP (6)          120000                 10                  8
# 1   TCP (6)           80000                  8                  7
# 2   TCP (6)           90000                 11                  9
# 3   TCP (6)           40000                  6                  3
# 4  UDP (17)           30000                  4                  2
#
#    Fwd Packet Length  Bwd Packet Length     Label
# 0               1200                800    BENIGN
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.dropna()
# Out:
#   Flow ID     Source IP Destination IP  Source Port  Destination Port  \
# 0      F1   192.168.0.2     172.16.0.3          443             51515
# 1      F2   192.168.0.5     172.16.0.3           80                80
# 2      F3   192.168.0.2    172.16.0.10          443               443
# 3      F4  192.168.0.10    172.16.0.11           21                22
# 4      F5   192.168.0.7     172.16.0.3           53                53
#
#    Protocol  Flow Duration   Total Fwd Packets  Total Bwd Packets  \
# 0   TCP (6)          120000                 10                  8
# 1   TCP (6)           80000                  8                  7
# 2   TCP (6)           90000                 11                  9
# 3   TCP (6)           40000                  6                  3
# 4  UDP (17)           30000                  4                  2
#
#    Fwd Packet Length  Bwd Packet Length     Label
# 0               1200                800    BENIGN
# ...

# %%
df.to_csv("updated.csv")

# %%
df.to_csv("updated.csv,index=false")

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(df['Source Port'],labels=df['Protocol'])
# Out:
# ([<matplotlib.patches.Wedge at 0x7c974f320470>,
# ...
#  [Text(0.253557760070033, 1.0703777194562056, 'TCP (6)'),
#   Text(-1.072631560526266, 0.24384736078741445, 'TCP (6)'),
#   Text(-0.23411706358473755, -1.074797283462542, 'TCP (6)'),
#   Text(1.0200404965814278, -0.4117248903502363, 'TCP (6)'),
#   Text(1.0859324312672032, -0.17535893111587306, 'UDP (17)')])

# %%
plt.figure(figsize=(10,8))
plt.subplot(2,2,1)
plt.pie(df['Source Port'],labels=df['Protocol'])
plt.suptitle("Source Port")
plt.subplot(2,2,2)
plt.scatter(df['Source Port'],df['Bwd Packet Length'],color='green')
plt.suptitle("Source Port vs Bwd Packet Length")
plt.xlabel("Source Port")
plt.ylabel("Bwd Packet Length")
# Out:
# Text(0, 0.5, 'Bwd Packet Length')
